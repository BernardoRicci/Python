# %% [markdown]
# <a href="https://colab.research.google.com/github/BernardoRicci/Python/blob/main/PiMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I'm going to generate N points on a 2D plane, then I'll take only ones inside the circle of radius 1. After that I'll calculate π multiplying for 4 the number of points in circle and dividing by the number of total points. After that I'll plot it.

# %%
import random
N=10**6
n=0
xin=[]  #for point inside the circle
yin=[]
xout=[]  #for point outside the circle
yout=[]
for i in range(N):
  x=random.uniform(-1,1)
  y=random.uniform(-1,1)
  if (x*x+y*y <=1):
    n+=1
    xin.append(x)
    yin.append(y)
  else:
    xout.append(x)
    yout.append(y)
pi=(4*n)/N
print("N=%d, points in circle=%d ,pi=%.6f" %(N,n,pi))

# Import modules 
import matplotlib.pyplot as plt
import math

plt.axis("square")
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.title("pi with MC method")
plt.scatter(xin,yin, color="green", marker=".")
plt.scatter(xout,yout, color="black", marker=".")

plt.show()
# Out:
# N=1000000, points in circle=785146 ,pi=3.140584
