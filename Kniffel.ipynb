# %% [markdown]
# <a href="https://colab.research.google.com/github/BernardoRicci/Python/blob/main/Kniffel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 6D dices, must determine distribution of number of rools it takes to achieve these combinations:
# 12345 ;
# 23456 ;
# kniffel(real poker) ;
# poker ;
# full.

# %%
import random


threeofkind = 0
fourofkind = 0
fullhouse = 0
kniffel = 0
sstraight = 0
lstraight = 0
misc = 0


def roll_dice():
    #Returns 5 randomly rolled dice
    dice = []
    for i in range(5):
        dice += [random.randint(1,6)]
        dice = sorted(dice)
        dice2 = set(dice)

        print(dice)
        print(dice2)
    return dice
    
def three_of_a_kind(dice):
    #Returns True or False if the dice are three of a kind
    if len(dice2) == 3:
        threeofkind += 1
    else:
        pass
 
def four_of_a_kind(dice):
    #Returns True or False if the dice are four of a kind
    if dice[0] == dice[-1]:
        pass
    elif len(dice2) == 2:
        if dice[0] == dice[1]:
            fourofkind += 1
    else:
        pass

def full_house(dice):
    #Returns True of False if the dice are a full house
    if len(dice2) == 2:
        if dice[0] == dice[1]:
            fullhouse += 1
        elif dice[-1] == dice[-2]:
            fullhouse += 1  
    else:
        pass
     
def small_straight(dice):
  #Returns True or False if the dice represent a small straight
    if dice == (1,2,3,4,5):
        sstraight += 1
    else:
        pass

    
def large_straight(dice):
    #Returns True or False if the dice represent a large straight
    
    if dice == (2,3,4,5,6):
        lstraight += 1
    else:
        pass
 
def kniffel(dice):
    #Returns True or False if the dice represent Yahtzee
    if len(dice2) == 1:
        kniffel += 1
    else:
        pass

def misc(dice):
  #None of others
    if len(dice2) == 5 or len(dice2) == 4:
        misc += 1
    
    

def main():
    total_rolls = 0.0
    N=50
    
    for i in range(N):
        roll_dice()
    
        three_of_a_kind(dice)
        four_of_a_kind(dice)
        full_house(dice)
        small_straight(dice)
        large_straight(dice)
        kniffel(dice)
        misc(dice)

    return
    

main()
# Out:
# [1]
# {1}
# [1, 2]
# {1, 2}
# [1, 2, 6]
# {1, 2, 6}
# [1, 2, 2, 6]
# {1, 2, 6}
# [1, 2, 2, 6, 6]
# {1, 2, 6}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3f844083797f> in <module>()
#     104
#     105
# --> 106 main()
#     107
#
# <ipython-input-32-3f844083797f> in main()
#      93         roll_dice()
#      94
# ---> 95         three_of_a_kind(dice)
#      96         four_of_a_kind(dice)
#      97         full_house(dice)
#
# NameError: name 'dice' is not defined

# %%
def roll_dice():
    #Returns 5 randomly rolled dice
    dice = []
    for i in range(5):
        dice += [random.randint(1,6)]
        dice = sorted(dice)

    return dice

def three_of_a_kind(dice_set):
    #Returns True or False if the dice are three of a kind
    if len(dice_set) == 3:
        return True
    else:
        return False

dice = roll_dice()
print(dice)
print(set(dice))

threeofkind = three_of_a_kind(set(dice))
print(threeofkind)
threeofkind = three_of_a_kind({1,1,1,3,4})
print(threeofkind)
# Out:
# [1, 2, 2, 3, 5]
# {1, 2, 3, 5}
# False
# True
